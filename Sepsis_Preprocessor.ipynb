# %%
dir = './data/'
import pandas as pd
import numpy as np
import pm4py

# %%
# Read event_log from XES file and preprocess
def import_xes(file_path):
    event_log = pm4py.read_xes(file_path)
    event_log['time:timestamp'] = pd.to_datetime(event_log['time:timestamp'], utc=True)
    return event_log

event_log = import_xes(dir + '/Hospital_log.xes')
# Out:
# parsing log, completed traces ::   0%|          | 0/1143 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4     event_log['time:timestamp'] = pd.to_datetime(event_log['time:timestamp'], utc=True)
#       5     return event_log
# ----> 7 event_log = import_xes(dir + '/Hospital_log.xes')
#
# Cell In[11], line 4, in import_xes(file_path)
#       2 def import_xes(file_path):
#       3     event_log = pm4py.read_xes(file_path)
# ----> 4     event_log['time:timestamp'] = pd.to_datetime(event_log['time:timestamp'], utc=True)
#       5     return event_log
#
# File c:\Users\haert\AppData\Local\Programs\Python\Python310\lib\site-packages\pm4py\objects\log\log.py:50, in EventStream.__getitem__(self, key)
#      49 def __getitem__(self, key):
# ---> 50     return self._list[key]
#
# TypeError: list indices must be integers or slices, not str

# %%
pd.DataFrame(event_log)
# Out:
#                                                     0    \
# 0     [InfectionSuspected, org:group, DiagnosticBloo...
# 1     [InfectionSuspected, org:group, DiagnosticBloo...
# 2     [InfectionSuspected, org:group, DiagnosticBloo...
# 3     [InfectionSuspected, org:group, DiagnosticBloo...
# 4     [InfectionSuspected, org:group, DiagnosticBloo...
# ...                                                 ...
# 1045  [InfectionSuspected, org:group, DiagnosticBloo...
# 1046  [InfectionSuspected, org:group, DiagnosticBloo...
# 1047  [InfectionSuspected, org:group, DiagnosticBloo...
# 1048  [InfectionSuspected, org:group, DiagnosticBloo...
# 1049  [InfectionSuspected, org:group, DiagnosticBloo...
#
#                                                     1    \
# 0     [Leucocytes, org:group, lifecycle:transition, ...
# 1     [org:group, lifecycle:transition, concept:name...
# 2     [org:group, lifecycle:transition, concept:name...
# 3     [org:group, lifecycle:transition, concept:name...
# 4     [org:group, lifecycle:transition, concept:name...
# ...                                                 ...
# 1045  [org:group, lifecycle:transition, concept:name...
# 1046  [org:group, lifecycle:transition, concept:name...
# 1047  [org:group, lifecycle:transition, concept:name...
# 1048  [org:group, lifecycle:transition, concept:name...
# 1049  [org:group, lifecycle:transition, concept:name...
#
#                                                     2    \
# 0     [CRP, org:group, lifecycle:transition, concept...
# 1     [CRP, org:group, lifecycle:transition, concept...
# 2     [org:group, lifecycle:transition, concept:name...
# 3     [org:group, lifecycle:transition, concept:name...
# 4     [org:group, lifecycle:transition, concept:name...
# ...                                                 ...
# 1045  [org:group, lifecycle:transition, concept:name...
# 1046  [org:group, lifecycle:transition, concept:name...
# 1047  [org:group, lifecycle:transition, concept:name...
# 1048  [org:group, lifecycle:transition, concept:name...
# 1049  [org:group, lifecycle:transition, concept:name...
#
#                                                     3    \
# 0     [org:group, LacticAcid, lifecycle:transition, ...
# 1     [org:group, LacticAcid, lifecycle:transition, ...
# 2     [Leucocytes, org:group, lifecycle:transition, ...
# 3     [CRP, org:group, lifecycle:transition, concept...
# 4     [org:group, lifecycle:transition, concept:name...
# ...                                                 ...
# 1045  [Leucocytes, org:group, lifecycle:transition, ...
# 1046                                               None
# 1047                                               None
# 1048  [Leucocytes, org:group, lifecycle:transition, ...
# 1049                                               None
#
#                                                     4    \
# 0     [org:group, lifecycle:transition, concept:name...
# 1     [Leucocytes, org:group, lifecycle:transition, ...
# 2     [CRP, org:group, lifecycle:transition, concept...
# 3     [org:group, LacticAcid, lifecycle:transition, ...
# 4     [CRP, org:group, lifecycle:transition, concept...
# ...                                                 ...
# 1045  [CRP, org:group, lifecycle:transition, concept...
# 1046                                               None
# 1047                                               None
# 1048  [org:group, LacticAcid, lifecycle:transition, ...
# 1049                                               None
#
#                                                     5    \
# 0     [org:group, lifecycle:transition, concept:name...
# 1     [org:group, lifecycle:transition, concept:name...
# 2     [org:group, lifecycle:transition, concept:name...
# 3     [Leucocytes, org:group, lifecycle:transition, ...
# 4     [Leucocytes, org:group, lifecycle:transition, ...
# ...                                                 ...
# 1045  [org:group, LacticAcid, lifecycle:transition, ...
# 1046                                               None
# 1047                                               None
# 1048  [CRP, org:group, lifecycle:transition, concept...
# 1049                                               None
#
#                                                     6    \
# 0     [org:group, lifecycle:transition, concept:name...
# 1     [org:group, lifecycle:transition, concept:name...
# 2     [org:group, lifecycle:transition, concept:name...
# 3     [org:group, lifecycle:transition, concept:name...
# 4     [org:group, LacticAcid, lifecycle:transition, ...
# ...                                                 ...
# 1045  [org:group, lifecycle:transition, concept:name...
# 1046                                               None
# 1047                                               None
# 1048  [org:group, lifecycle:transition, concept:name...
# 1049                                               None
#
#                                                     7    \
# 0     [org:group, lifecycle:transition, concept:name...
# 1     [org:group, lifecycle:transition, concept:name...
# 2     [org:group, lifecycle:transition, concept:name...
# 3     [org:group, lifecycle:transition, concept:name...
# 4     [org:group, lifecycle:transition, concept:name...
# ...                                                 ...
# 1045  [org:group, lifecycle:transition, concept:name...
# 1046                                               None
# 1047                                               None
# 1048  [org:group, lifecycle:transition, concept:name...
# 1049                                               None
#
#                                                     8    \
# 0     [org:group, lifecycle:transition, concept:name...
# 1     [org:group, lifecycle:transition, concept:name...
# 2     [org:group, lifecycle:transition, concept:name...
# 3     [org:group, lifecycle:transition, concept:name...
# 4                                                  None
# ...                                                 ...
# 1045  [CRP, org:group, lifecycle:transition, concept...
# 1046                                               None
# 1047                                               None
# 1048  [org:group, lifecycle:transition, concept:name...
# 1049                                               None
#
#                                                     9    ...   175   176  \
# 0     [CRP, org:group, lifecycle:transition, concept...  ...  None  None
# 1     [CRP, org:group, lifecycle:transition, concept...  ...  None  None
# 2     [Leucocytes, org:group, lifecycle:transition, ...  ...  None  None
# 3     [Leucocytes, org:group, lifecycle:transition, ...  ...  None  None
# 4                                                  None  ...  None  None
# ...                                                 ...  ...   ...   ...
# 1045  [Leucocytes, org:group, lifecycle:transition, ...  ...  None  None
# 1046                                               None  ...  None  None
# 1047                                               None  ...  None  None
# 1048  [CRP, org:group, lifecycle:transition, concept...  ...  None  None
# 1049                                               None  ...  None  None
#
#        177   178   179   180   181   182   183   184
# 0     None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 1045  None  None  None  None  None  None  None  None
# 1046  None  None  None  None  None  None  None  None
# 1047  None  None  None  None  None  None  None  None
# 1048  None  None  None  None  None  None  None  None
# 1049  None  None  None  None  None  None  None  None
#
# [1050 rows x 185 columns]
